# %%
from bs4 import BeautifulSoup
import requests

headers = {
    'authority': 'www.realtor.com',
    'sec-ch-ua': '"Google Chrome";v="89", "Chromium";v="89", ";Not A Brand";v="99"',
    'sec-ch-ua-mobile': '?0',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.114 Safari/537.36',
    'accept': '*/*',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://www.realtor.com/realestateandhomes-search/San-Francisco_CA',
    'accept-language': 'en-US,en;q=0.9',
}
#'Accept-Encoding': 'identity'

url = 'https://www.realtor.com/realestateandhomes-search/San-Francisco_CA'

response=requests.get(url,headers=headers)

# %%
soup=BeautifulSoup(response.content,'lxml')


for item in soup.select('.component_property-card'):
	try:
		print('**********')
		#print(item)
		print(item.select('[data-label=pc-price]')[0].get_text())
		print(item.select('img')[0]['data-src'])
		print(item.select('.summary-wrap')[0].get_text())
		print(item.select('.address')[0].get_text())
		print(item.select('.property-meta')[0].get_text())
		print(item.select('.special-feature-list')[0].get_text())
		
	except Exception as e:
		#raise e
		print('')
# Out:
# **********
# $1,950,000
# https://ap.rdcpix.com/75668a22d1228ce86408333895b844dbl-m580102989od-w480_h360.jpg
# $1,950,0002bed2bath1,000sqft3,049sqft lot2955 Sacramento St, San Francisco, CA 94115
# 2955 Sacramento St, San Francisco, CA 94115
# 2bed2bath1,000sqft3,049sqft lot
#
# **********
# $695,000
# https://ap.rdcpix.com/f8fbeaa357fec7642cea89ffcc8b3c56l-m2045157562od-w480_h360.jpg
# $695,0001bed1bath5,876sqft lot201 Sansome St Unit 905, San Francisco, CA 94104
# 201 Sansome St Unit 905, San Francisco, CA 94104
# 1bed1bath5,876sqft lot
#
# **********
# $375,000
# https://ap.rdcpix.com/9b2fd413e31cdedb896becf9eb587dafl-m4159605400od-w480_h360.jpg
# $375,000Studio1bath520sqft0.42acre lot631 Ofarrell St Apt 511, San Francisco, CA 94109
# 631 Ofarrell St Apt 511, San Francisco, CA 94109
# Studio1bath520sqft0.42acre lot
#
# **********
#
# **********
# $899,000
#
# **********
# $1,095,000
#
# **********
# $2,800,000
#
# **********
# $1,895,000
#
# **********
# $1,195,000
#
# **********
# $599,000
#
# **********
# $1,125,000
#
# **********
# $865,000
#
# **********
#
# **********
# $1,198,000
#
# **********
# $1,415,000
#
# **********
# $775,000
#
# **********
# $1,395,000
#
# **********
# $899,000
#
# **********
# $1,448,000
#
# **********
# $838,000
#
# **********
# $1,079,000
#
# **********
#
# **********
# $895,000
#
# **********
# $1,870,000
#
# **********
# $888,000
#
# **********
# $1,498,000
#
# **********
# $1,690,000
#
# **********
# $1,398,000
#
# **********
# $995,000
#
# **********
# $950,000
#
# **********
#
# **********
# $3,798,000
#
# **********
# $1,695,000
#
# **********
# $2,795,000
#
# **********
# $1,498,000
#
# **********
# $1,078,000
#
# **********
# $1,595,000
#
# **********
# $925,000
#
# **********
# $1,225,000
#
# **********
#
# **********
# $1,745,000
#
# **********
# $1,848,000
#
# **********
# $2,095,000
#
# **********
# $2,225,000
#
# **********
# $2,895,000
#
# **********
# $4,000,000
#
# **********
# $1,188,000
#
# **********
